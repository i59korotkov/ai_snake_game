# %%
import sys
sys.path.append('../')

import random
from src.game import SnakeGame, Direction
import matplotlib.pyplot as plt

# %%
game = SnakeGame()
plt.imshow(game.get_image());

# %%
game.update(
    random.choice(list(Direction)),
    random.choice(list(Direction)),
)
plt.imshow(game.get_image());

# %%
game.step
# Out:
# 7
